# %%
import numpy as np
import pandas as pd
import re

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/after_transcription.csv', low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0     BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0           0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1           1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2           2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3           3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4           4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6  is_inpatient         DOB  DOD  Gender  Race  \
# 0                 NaN           1.0  1943-01-01  NaN       1     1
# 1                 NaN           1.0  1943-01-01  NaN       1     1
# 2                 NaN           1.0  1943-01-01  NaN       1     1
# 3                 NaN           1.0  1914-03-01  NaN       2     2
# 4                 NaN           1.0  1938-04-01  NaN       2     1
#
#   RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0                     0     39     230                   12
# 1                     0     39     230                   12
# 2                     0     39     230                   12
# 3                     0      1     360                   12
# 4                     Y     45     780                   12
#
#    NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                   12                      1                         2
# 1                   12                      1                         2
# 2                   12                      1                         2
# 3                   12                      2                         1
# 4                   12                      2                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                          1                   2                           2
# 1                          1                   2                           2
# 2                          1                   2                           2
# 3                          1                   2                           2
# 4                          1                   2                           1
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       1                     1                          1
# 2                       1                     1                          1
# 3                       1                     1                          2
# 4                       1                     2                          1
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         2                                1
# 2                         2                                1
# 3                         2                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   1                     36000                   3204
# 2                   1                     36000                   3204
# 3                   1                      5000                   1068
# 4                   2                     21260                   2136
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt         Age  \
# 0                        60                     70  24208 days
# 1                        60                     70  24349 days
# 2                        60                     70  24366 days
# 3                       250                    320  34684 days
# 4                       120                    100  26067 days
#
#                                                 Note
# 0  PROCEDURE:,  Upper endoscopy.,PREOPERATIVE DIA...
# 1  PREOPERATIVE DIAGNOSES: , Bilateral cleft lip ...
# 2  ALLOWED CONDITIONS:,  Lateral epicondylitis, r...
# 3  HISTORY: , The patient is a 5-1/2-year-old, wh...
# 4  HISTORY OF PRESENT ILLNESS: , The patient is a...

# %%
time_cols = ['ClaimStartDt', 'ClaimEndDt', 'AdmissionDt', 'DischargeDt', 'DOB']
for col in time_cols:
    df[col] = pd.to_datetime(df[col])

# %%
df.dtypes
# Out:
# Unnamed: 0                                  int64
# BeneID                                     object
# ClaimID                                    object
# ClaimStartDt                       datetime64[ns]
# ClaimEndDt                         datetime64[ns]
# Provider                                   object
# InscClaimAmtReimbursed                      int64
# AttendingPhysician                         object
# OperatingPhysician                         object
# OtherPhysician                             object
# AdmissionDt                        datetime64[ns]
# ClmAdmitDiagnosisCode                      object
# DeductibleAmtPaid                         float64
# DischargeDt                        datetime64[ns]
# DiagnosisGroupCode                         object
# ClmDiagnosisCode_1                         object
# ClmDiagnosisCode_2                         object
# ClmDiagnosisCode_3                         object
# ClmDiagnosisCode_4                         object
# ClmDiagnosisCode_5                         object
# ClmDiagnosisCode_6                         object
# ClmDiagnosisCode_7                         object
# ClmDiagnosisCode_8                         object
# ClmDiagnosisCode_9                         object
# ClmDiagnosisCode_10                        object
# ClmProcedureCode_1                        float64
# ClmProcedureCode_2                        float64
# ClmProcedureCode_3                        float64
# ClmProcedureCode_4                        float64
# ClmProcedureCode_5                        float64
# ClmProcedureCode_6                        float64
# is_inpatient                              float64
# DOB                                datetime64[ns]
# DOD                                        object
# Gender                                      int64
# Race                                        int64
# RenalDiseaseIndicator                      object
# State                                       int64
# County                                      int64
# NoOfMonths_PartACov                         int64
# NoOfMonths_PartBCov                         int64
# ChronicCond_Alzheimer                       int64
# ChronicCond_Heartfailure                    int64
# ChronicCond_KidneyDisease                   int64
# ChronicCond_Cancer                          int64
# ChronicCond_ObstrPulmonary                  int64
# ChronicCond_Depression                      int64
# ChronicCond_Diabetes                        int64
# ChronicCond_IschemicHeart                   int64
# ChronicCond_Osteoporasis                    int64
# ChronicCond_rheumatoidarthritis             int64
# ChronicCond_stroke                          int64
# IPAnnualReimbursementAmt                    int64
# IPAnnualDeductibleAmt                       int64
# OPAnnualReimbursementAmt                    int64
# OPAnnualDeductibleAmt                       int64
# Age                                        object
# Note                                       object
# dtype: object

# %%
df['Age'] = df['Age'].str.split(' ', expand=True)[0].astype(int)/365

# %%
df['Age'] = df['Age'].round()

# %%
df.head(1)
# Out:
#    Unnamed: 0     BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0           0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6  is_inpatient        DOB  DOD  Gender  Race  \
# 0                 NaN           1.0 1943-01-01  NaN       1     1
#
#   RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0                     0     39     230                   12
#
#    NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                   12                      1                         2
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                          1                   2                           2
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt   Age  \
# 0                        60                     70  66.0
#
#                                                 Note
# 0  PROCEDURE:,  Upper endoscopy.,PREOPERATIVE DIA...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['Note'] = df['Note'].fillna('').astype(str)
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()

df['Note'] = df['Note'].apply(clean_text)

# %%
df['note_length'] = df['Note'].str.len()

# %%
df['word_count'] = df['Note'].str.split().str.len()

# %%
df['sentence_count'] = df['Note'].str.count(r'[.!?]')

# %%
df.sample(2)['word_count']
# Out:
# 508641    208
# 303694    144
# Name: word_count, dtype: int64

# %%
medical_terms = [
    'surgery', 'procedure', 'incision', 'biopsy',
    'tumor', 'fracture', 'infection', 'chronic',
    'acute', 'diabetes', 'cardiac', 'renal',
    'malignant', 'therapy', 'anesthesia'
]

# %%
df["medical_term_count"] = df["Note"].apply(
    lambda x: sum(term in x for term in medical_terms)
)

# %%
df.sample()
# Out:
#             BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 543025  BENE154743  CLM394126   2009-06-02 2009-06-02  PRV53790
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 543025                     200          PHY414991          PHY414991
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 543025      PHY431212         NaT                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 543025         NaT                NaN              25070               2808
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 543025               5859               5853               2753
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 543025               3572              78722                NaN
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 543025                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 543025                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  is_inpatient        DOB  DOD  \
# 543025                 NaN                 NaN           0.0 1930-12-01  NaN
#
#         Gender  Race RenalDiseaseIndicator  State  County  \
# 543025       1     1                     Y     21     150
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 543025                   12                   12                      2
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 543025                         2                          1
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 543025                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 543025                       2                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 543025                          1                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 543025                                2                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 543025                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt   Age  \
# 543025                      1270                    800  79.0
#
#                                                      Note  note_length  \
# 543025  procedure medial branch rhizotomy lumbosacral ...         3779
#
#         word_count  sentence_count  medical_term_count
# 543025         588               0                   2

# %%
general_words = [
    "routine", "follow up",
    "as discussed", "as planned",
    "normal", "stable"
]

df["general_word_count"] = df["Note"].apply(
    lambda x: sum(phrase in x for phrase in general_words)
)

# %%
df["short_note_flag"] = (df["word_count"] < 10).astype(int)

# %%
high_cost_threshold = df["InscClaimAmtReimbursed"].quantile(0.90)
df["High_Cost_Flag"] = (
    df["InscClaimAmtReimbursed"] > high_cost_threshold
).astype(int)

# %%
df.sample()['High_Cost_Flag']
# Out:
# 193497    0
# Name: High_Cost_Flag, dtype: int64

# %%
df["highcost_shortnote"] = (
    df["High_Cost_Flag"] &
    df["short_note_flag"]
).astype(int)

# %%
diag_cols = [col for col in df.columns if "ClmDiagnosisCode_" in col]
df["diag_count"] = df[diag_cols].notna().sum(axis=1)

# %%
proc_cols = [col for col in df.columns if "ClmProcedureCode_" in col]
df["procedure_count"] = df[proc_cols].notna().sum(axis=1)

# %%
df["ClaimStartDt"] = pd.to_datetime(df["ClaimStartDt"])
df["ClaimEndDt"] = pd.to_datetime(df["ClaimEndDt"])

df["stay_len"] = (
    df["ClaimEndDt"] - df["ClaimStartDt"]
).dt.days.fillna(0)

# %%
df["Claim_After_Death"] = (
    df["DOD"].notna() &
    (df["ClaimStartDt"] > pd.to_datetime(df["DOD"]))
).astype(int)

# %%
df.sample()['stay_len']
# Out:
# 415717    0
# Name: stay_len, dtype: int64

# %%
df.drop(columns=["Note", "sentence_count"], inplace=True)

# %%
df.shape
# Out:
# (558211, 67)

# %%
df.to_csv('before_aggregation.csv')

# %%
df.sample()
# Out:
#            BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 40419  BENE158965  CLM34233   2009-01-17 2009-01-24  PRV51244
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 40419                    4000          PHY416029          PHY371043
#
#       OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 40419            NaN  2009-01-17                 78079             1068.0
#
#       DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 40419  2009-01-24                307               4280               4254
#
#       ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 40419              42731                496              53081
#
#       ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 40419                515              41400               2449
#
#       ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 40419               5990                 NaN              9929.0
#
#        ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 40419                 NaN                 NaN                 NaN
#
#        ClmProcedureCode_5  ClmProcedureCode_6  is_inpatient        DOB  DOD  \
# 40419                 NaN                 NaN           1.0 1934-08-01  NaN
#
#        Gender  Race RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 40419       1     1                     0      4     730                   12
#
#        NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 40419                   12                      1                         1
#
#        ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 40419                          2                   2
#
#        ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# 40419                           1                       1
#
#        ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 40419                     1                          1
#
#        ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 40419                         1                                1
#
#        ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 40419                   2                     16240                   3204
#
#        OPAnnualReimbursementAmt  OPAnnualDeductibleAmt   Age  note_length  \
# 40419                      1080                   1270  75.0         1132
#
#        word_count  medical_term_count  general_word_count  short_note_flag  \
# 40419         181                   3                   0                0
#
#        High_Cost_Flag  highcost_shortnote  diag_count  procedure_count  \
# 40419               1                   0           9                1
#
#        stay_len  Claim_After_Death
# 40419         7                  0

# %%
diag_cols = [col for col in df.columns if "ClmDiagnosisCode_" in col]
proc_cols = [col for col in df.columns if "ClmProcedureCode_" in col]

date_cols = [
    "ClaimStartDt",
    "ClaimEndDt",
    "AdmissionDt",
    "DischargeDt",
    "DOB",
    "DOD"
]

physician_cols = [
    "AttendingPhysician",
    "OperatingPhysician",
    "OtherPhysician"
]

text_cols = ["Note"]
# id_cols = ["ClaimID"]

columns_to_drop = (
    diag_cols +
    proc_cols +
    date_cols +
    physician_cols +
    text_cols
    # id_cols
)

claims = df.drop(columns=columns_to_drop, errors="ignore")

# %%
claims.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed  \
# 0  BENE11001  CLM46614  PRV55912                   26000
# 1  BENE11001  CLM66048  PRV55907                    5000
# 2  BENE11001  CLM68358  PRV56046                    5000
# 3  BENE11011  CLM38412  PRV52405                    5000
# 4  BENE11014  CLM63689  PRV56614                   10000
#
#   ClmAdmitDiagnosisCode  DeductibleAmtPaid DiagnosisGroupCode  is_inpatient  \
# 0                  7866             1068.0                201           1.0
# 1                  6186             1068.0                750           1.0
# 2                 29590             1068.0                883           1.0
# 3                   431             1068.0                067           1.0
# 4                 78321             1068.0                975           1.0
#
#    Gender  Race RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0       1     1                     0     39     230                   12
# 1       1     1                     0     39     230                   12
# 2       1     1                     0     39     230                   12
# 3       2     2                     0      1     360                   12
# 4       2     1                     Y     45     780                   12
#
#    NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0                   12                      1                         2
# 1                   12                      1                         2
# 2                   12                      1                         2
# 3                   12                      2                         1
# 4                   12                      2                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                          1                   2                           2
# 1                          1                   2                           2
# 2                          1                   2                           2
# 3                          1                   2                           2
# 4                          1                   2                           1
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# 1                       1                     1                          1
# 2                       1                     1                          1
# 3                       1                     1                          2
# 4                       1                     2                          1
#
#    ChronicCond_Osteoporasis  ChronicCond_rheumatoidarthritis  \
# 0                         2                                1
# 1                         2                                1
# 2                         2                                1
# 3                         2                                1
# 4                         2                                2
#
#    ChronicCond_stroke  IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                   1                     36000                   3204
# 1                   1                     36000                   3204
# 2                   1                     36000                   3204
# 3                   1                      5000                   1068
# 4                   2                     21260                   2136
#
#    OPAnnualReimbursementAmt  OPAnnualDeductibleAmt   Age  note_length  \
# 0                        60                     70  66.0         1309
# 1                        60                     70  67.0         5078
# 2                        60                     70  67.0         6977
# 3                       250                    320  95.0         4473
# 4                       120                    100  71.0         2261
#
#    word_count  medical_term_count  general_word_count  short_note_flag  \
# 0         207                   1                   2                0
# 1         880                   5                   1                0
# 2        1152                   1                   0                0
# 3         700                   5                   2                0
# 4         408                   1                   0                0
#
#    High_Cost_Flag  highcost_shortnote  diag_count  procedure_count  stay_len  \
# 0               1                   0           9                0         6
# 1               1                   0           3                1         2
# 2               1                   0           6                0         3
# 3               1                   0           9                1         8
# 4               1                   0           9                1        17
#
#    Claim_After_Death
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
claims.shape
# Out:
# (558211, 42)

# %%
claims["Inpatient_Claim"] = claims["is_inpatient"]
claims["Outpatient_Claim"] = 1 - claims["is_inpatient"]

# %%
aggregation_dict = {
    "InscClaimAmtReimbursed": ["sum", "mean", "std", "max", "median", "min"],
    "DeductibleAmtPaid": ["sum", "mean"],
    "diag_count": "mean",
    "procedure_count": "mean",
    "stay_len": "mean",
    "Age": ["mean", "std"],

    "NoOfMonths_PartACov": "mean",
    "NoOfMonths_PartBCov": "mean",

    "ChronicCond_Alzheimer": "mean",
    "ChronicCond_Heartfailure": "mean",
    "ChronicCond_KidneyDisease": "mean",
    "ChronicCond_ObstrPulmonary":"mean",
    "ChronicCond_Depression": "mean",
    "ChronicCond_Diabetes": "mean",
    "ChronicCond_IschemicHeart": "mean",
    "ChronicCond_Osteoporasis": "mean",
    "ChronicCond_rheumatoidarthritis": "mean",
    "ChronicCond_stroke": "mean",

    "IPAnnualReimbursementAmt": "mean",
    "OPAnnualReimbursementAmt": "mean",
    "IPAnnualDeductibleAmt": "mean",
    "OPAnnualDeductibleAmt": "mean",
    
    "word_count": ["mean", "median"],
    "medical_term_count": "mean",
    "general_word_count": "mean",
    
    "short_note_flag": "mean",
    "highcost_shortnote": "mean",
    "High_Cost_Flag": "mean",
    "Claim_After_Death": "sum",

    "is_inpatient": "mean",
    
    "BeneID": "nunique",
    "ClaimID": "count",
    "Inpatient_Claim": "sum",
    "Outpatient_Claim": "sum"
}

# %%
df_provider = claims.groupby("Provider").agg(aggregation_dict)

# %%
df_provider.shape
# Out:
# (5410, 42)

# %%
df_labels = pd.read_csv('../data/Train-1542865627584.csv')

# %%
df_labels.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
df_provider.head()
# Out:
#          InscClaimAmtReimbursed                                                \
#                             sum         mean           std    max  median min
# Provider
# PRV51001                 104640  4185.600000  10796.091144  42000   400.0  10
# PRV51003                 605670  4588.409091   7309.794729  57000  1750.0   0
# PRV51004                  52170   350.134228    689.963754   3300    70.0   0
# PRV51005                 280910   241.124464    491.556392   4080    70.0   0
# PRV51007                  33710   468.194444   1433.769116  10000    80.0   0
#
#          DeductibleAmtPaid             diag_count procedure_count  stay_len  \
#                        sum        mean       mean            mean      mean
# Provider
# PRV51001            5340.0  213.600000   3.200000        0.120000  1.440000
# PRV51003           66286.0  502.166667   5.250000        0.363636  3.674242
# PRV51004             310.0    2.080537   2.583893        0.000000  1.429530
# PRV51005            3700.0    3.175966   2.588841        0.000000  1.088412
# PRV51007            3264.0   45.333333   2.986111        0.013889  0.958333
#
#                 Age            NoOfMonths_PartACov NoOfMonths_PartBCov  \
#                mean        std                mean                mean
# Provider
# PRV51001  78.160000  11.915256           12.000000           12.000000
# PRV51003  69.590909  13.461823           11.818182           11.871212
# PRV51004  71.778523  12.918061           11.865772           11.959732
# PRV51005  70.082403  13.357434           11.907296           11.939914
# PRV51007  68.791667  14.628679           11.833333           11.833333
#
#          ChronicCond_Alzheimer ChronicCond_Heartfailure  \
#                           mean                     mean
# Provider
# PRV51001              1.400000                 1.240000
# PRV51003              1.575758                 1.393939
# PRV51004              1.570470                 1.409396
# PRV51005              1.634335                 1.416309
# PRV51007              1.638889                 1.444444
#
#          ChronicCond_KidneyDisease ChronicCond_ObstrPulmonary  \
#                               mean                       mean
# Provider
# PRV51001                  1.320000                   1.600000
# PRV51003                  1.515152                   1.689394
# PRV51004                  1.664430                   1.724832
# PRV51005                  1.564807                   1.746781
# PRV51007                  1.694444                   1.777778
#
#          ChronicCond_Depression ChronicCond_Diabetes  \
#                            mean                 mean
# Provider
# PRV51001               1.640000             1.160000
# PRV51003               1.590909             1.242424
# PRV51004               1.577181             1.295302
# PRV51005               1.583691             1.314163
# PRV51007               1.597222             1.319444
#
#          ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
#                               mean                     mean
# Provider
# PRV51001                  1.080000                 1.760000
# PRV51003                  1.151515                 1.750000
# PRV51004                  1.275168                 1.671141
# PRV51005                  1.231760                 1.704721
# PRV51007                  1.291667                 1.708333
#
#          ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
#                                     mean               mean
# Provider
# PRV51001                        1.680000           1.760000
# PRV51003                        1.712121           1.909091
# PRV51004                        1.691275           1.885906
# PRV51005                        1.715880           1.893562
# PRV51007                        1.694444           1.833333
#
#          IPAnnualReimbursementAmt OPAnnualReimbursementAmt  \
#                              mean                     mean
# Provider
# PRV51001             17606.000000              2615.200000
# PRV51003              7568.181818              2678.181818
# PRV51004              4351.879195              2194.899329
# PRV51005              3623.991416              2109.733906
# PRV51007              3050.000000              1729.722222
#
#          IPAnnualDeductibleAmt OPAnnualDeductibleAmt  word_count         \
#                           mean                  mean        mean median
# Provider
# PRV51001            897.120000            463.920000  537.280000  507.0
# PRV51003            931.424242            737.121212  458.977273  372.5
# PRV51004            434.953020            622.751678  511.402685  403.0
# PRV51005            379.162232            636.328755  486.928755  428.0
# PRV51007            445.000000            469.722222  428.208333  353.5
#
#          medical_term_count general_word_count short_note_flag  \
#                        mean               mean            mean
# Provider
# PRV51001           2.280000           1.200000        0.000000
# PRV51003           2.515152           1.045455        0.022727
# PRV51004           2.751678           1.080537        0.006711
# PRV51005           2.706438           1.097854        0.015451
# PRV51007           2.513889           0.944444        0.055556
#
#          highcost_shortnote High_Cost_Flag Claim_After_Death is_inpatient  \
#                        mean           mean               sum         mean
# Provider
# PRV51001           0.000000       0.200000                 0     0.200000
# PRV51003           0.022727       0.469697                 0     0.469697
# PRV51004           0.000000       0.060403                 0     0.000000
# PRV51005           0.000000       0.023176                 0     0.000000
# PRV51007           0.013889       0.055556                 0     0.041667
#
#           BeneID ClaimID Inpatient_Claim Outpatient_Claim
#          nunique   count             sum              sum
# Provider
# PRV51001      24      25             5.0             20.0
# PRV51003     117     132            62.0             70.0
# PRV51004     138     149             0.0            149.0
# PRV51005     495    1165             0.0           1165.0
# PRV51007      58      72             3.0             69.0

# %%
df_provider.columns = [
    "_".join(col).strip() if isinstance(col, tuple) else col
    for col in df_provider.columns
]
df_provider = df_provider.reset_index()

# %%
df_provider.to_csv('before_final.csv')
